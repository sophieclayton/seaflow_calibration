# %%
% matplotlib inline

import numpy as np
import pandas as pd
import seaflowpy as sfp

import matplotlib.pyplot as plt

# %%
bead_data = sfp.EVT('../data/calsettings10_13_2015.evt', transform=False, columns=["fsc_small", "D1","D2"])

bead_data.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409856 entries, 0 to 409855
# Data columns (total 3 columns):
# D1           409856 non-null float64
# D2           409856 non-null float64
# fsc_small    409856 non-null float64
# dtypes: float64(3)
# memory usage: 9.4 MB

# %%
fig1 = plt.figure(figsize=(20,20))

plt.scatter(bead_data.df['fsc_small'], bead_data.df['D1'], marker ='.')
plt.show()
